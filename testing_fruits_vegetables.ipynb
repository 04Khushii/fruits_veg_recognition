# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Test Set Image Processing

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    '/content/drive/MyDrive/fruits_vegetable_dataset/test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64, 64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 359 files belonging to 36 classes.

# %% [markdown]
# ##Loading the Model

# %%
cnn = tf.keras.models.load_model("/content/trained_model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# #Performing Prediction on Single Image

# %%
#Test Image Visualization
import cv2
image_path = '/content/drive/MyDrive/fruits_vegetable_dataset/test/beetroot/Image_2.jpg'
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# #Testing Model

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = cnn.predict(input_arr)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step

# %%
print(predictions)
# Out:
# [[2.71392772e-13 4.23045904e-11 1.00000000e+00 1.11165455e-09
#   5.82318590e-13 1.27845456e-10 2.07670721e-11 1.94169252e-13
#   7.23736175e-13 3.91947456e-18 5.70733807e-11 6.28360048e-13
#   9.72681497e-16 4.01428511e-13 1.64061536e-15 4.79062946e-15
#   8.10755458e-15 2.75925222e-18 3.72663023e-18 4.04303535e-11
#   4.43107736e-13 3.61445701e-17 6.36302296e-12 3.85298008e-14
#   2.01975599e-14 1.01286405e-17 5.79715746e-12 1.05365417e-13
#   3.81212040e-09 1.84088190e-15 2.71274126e-14 4.23300861e-15
#   1.62786830e-13 3.97874415e-15 1.50547335e-11 2.21535702e-12]]

# %%
# test_set.class_names

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 2

# %%
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#Single image Prediction
print("It's a {}".format(test_set.class_names[result_index]))
# Out:
# It's a beetroot
